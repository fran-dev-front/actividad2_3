# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import power_transform
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

#aea_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Inteligencia Artificial/WA_Fn-UseC_-HR-Employee-Attrition.csv')
aea_df = pd.read_csv('./WA_Fn-UseC_-HR-Employee-Attrition.csv')
aea_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
aea_df['OverTime']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: object

# %% [markdown]
# Carga la base de datos y realiza los análisis necesarios para responder a las siguientes
# preguntas:
# * a) ¿Cuántas y cuáles de las variables son numéricas?
#   1. i. ¿Cuántas y cuáles de estas variables numéricas son de valor entero?
#   #### 26
#   2. ii. ¿Cuántas y cuáles de estas variables numéricas son de valor real (flotante)?
#   #### 0
#   3. iii. De existir el caso, ¿cuántas y cuáles de estas variables numéricas se pueden
#   anular del problema? Justifica tu respuesta.
#   ####  Employee count: Todos los valores en la tabla son iguales no tiene valor en el analisis.
# ####  StandardHours: Es un valor unico no tiene relevancia en el analisis.
# ####  Employee Number: Es un identificador unico por empleado no tiene relevancia en el analisis.
#
# * b) ¿Cuántas y cuáles de las variables son categóricas?
#
#   ### 9
#
#   1. i. ¿Cuántas y cuáles de estas variables son binarias?
#
#
#
#       *   Attrition
#       *   Gender
#       *   Over18
#       *   OverTime
#
#   2. ii. ¿Cuántas y cuáles de estas variables son nominales? Indica el total de
#   niveles que tiene cada una de estas variables.
#
#
#
#       *   BusinessTravel
#       *   Department
#       *   EducationField
#       *   MaritalStatus
#
#
#   3. iii. ¿Cuántas y cuáles de estas variables son ordinales? Indica el total de niveles
#
#
#
#       *   PerformanceRating
#       *   Education
#       *   EnvironmentSatisfaction
#       *   JobInvolvement
#       *   JobSatisfaction
#       *   RelationshipSatisfaction
#       *   WorkLifeBalance
#
# que tiene cada una de estas variables.
# iv. De existir el caso, ¿cuántas y cuáles de estas variables categóricas se pueden
# anular del problema? Justifica tu respuesta.
#
# Over18 -> todos los valores son iguales
#
# * c) En esta base de datos y con base a la información dada, ¿existe alguna o algunas
# variables cuya clasificación en algún tipo de dato dependa del analista? ¿Cuáles y
# por qué?

# %%
aea_df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
aea_df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %%
aea_df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %%
aea_df.drop(columns=["Over18", "EmployeeCount", "EmployeeNumber", "StandardHours"], inplace=True)

# %%
Xtrain, XTestTemp, ytrain, ytestTemp = train_test_split(aea_df.drop('Attrition', axis=1), aea_df['Attrition'], test_size=0.30, random_state=1)
Xtest, Xval, ytest, yval = train_test_split(XTestTemp, ytestTemp, test_size=0.5, random_state=1)

# %%
Xtrain.select_dtypes(include=['number']).hist(figsize=(30,14), bins=20)
plt.show()

# %% [markdown]
# Yo suguiero transformar con MinMaxScaler() todas las columnas para que esten a la misma escala.

# %%
# Lista de los nombres de las 7 variables que trabajaremos en este ejercicio.
misdatos = Xtrain.select_dtypes(include=['number'])
variables_a_transformar = misdatos
variables_a_transformar
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 99     44        489                23          3                        2
# 785    40       1492                20          4                        1
# 918    51        237                 9          3                        4
# 1335   39        835                19          4                        4
# 1182   36        894                 1          4                        4
# ...   ...        ...               ...        ...                      ...
# 715    33        827                 1          4                        3
# 905    29        694                 1          3                        4
# 1096   40        898                 6          2                        3
# 235    43       1034                16          3                        4
# 1061   24        830                13          2                        4
#
#       HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 99            67               3         2                2           2042
# 785           61               3         3                4          10322
# 918           83               3         5                2          19847
# 1335          41               3         2                4           3902
# 1182          33               2         2                3           4374
# ...          ...             ...       ...              ...            ...
# 715           84               4         2                2           5488
# 905           87               2         4                4          16124
# 1096          38               3         4                4          16437
# 235           80               3         4                4          16064
# 1061          78               3         1                2           2033
#
#       ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 99    ...                  3                         3                 1
# 785   ...                  4                         4                 1
# 918   ...                  4                         1                 1
# 1335  ...                  3                         2                 3
# 1182  ...                  3                         3                 0
# ...   ...                ...                       ...               ...
# 715   ...                  3                         1                 1
# 905   ...                  3                         2                 2
# 1096  ...                  4                         4                 0
# 235   ...                  4                         3                 1
# 1061  ...                  3                         3                 1
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 99                   17                      3                4
# 785                  14                      6                3
# 918                  31                      5                2
# 1335                  7                      2                3
# 1182                  4                      6                3
# ...                 ...                    ...              ...
# 715                   6                      2                3
# 905                   9                      2                2
# 1096                 21                      2                3
# 235                  22                      3                3
# 1061                  1                      2                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 99                 3                   2                        1
# 785               11                  10                       11
# 918               29                  10                       11
# 1335               2                   2                        2
# 1182               3                   2                        1
# ...              ...                 ...                      ...
# 715                6                   5                        1
# 905                7                   7                        1
# 1096              21                   7                        7
# 235               17                  13                        1
# 1061               1                   0                        0
#
#       YearsWithCurrManager
# 99                       2
# 785                      1
# 918                     10
# 1335                     2
# 1182                     2
# ...                    ...
# 715                      2
# 905                      7
# 1096                     7
# 235                      9
# 1061                     0
#
# [1029 rows x 23 columns]

# %%
variables_a_transformar = ['DailyRate', 'DistanceFromHome',
       'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
len(variables_a_transformar)
# Out:
# 13

# %%
sns.set(rc={'figure.figsize':(45,14)})


columns = len(variables_a_transformar)
fig, axes = plt.subplots(5, columns)

for k in range(0,columns):

    # Datos originales ---------------------------------------------------------
    plt.subplot(5,columns,k+1)

    Transf0 = misdatos[variables_a_transformar[k]]         #  En esta línea se debe asignar a Transf0 los valores de cada variable "k" sin transformar.
    sns.histplot(Transf0, bins=10, kde=True)                             #  En este línea agrega el comando para obtener el histograma de Transf0 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Originales')



    # Datos transformados con raíz cuadrada ------------------------------------
    plt.subplot(5,columns,k+14)

    Transf1 = np.cbrt(misdatos[variables_a_transformar[k]])   #  En esta línea se debe aplicar la raíz cuadrada a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf1, bins=10, kde=True)                                #  En este línea agrega el comando para obtener el histograma de Transf1 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Raíz Cuadrada')



    # Datos transformados con logaritmo natural --------------------------------
    plt.subplot(5,columns,k+27)

    Transf2 = np.log(misdatos[variables_a_transformar[k]]+1)  #  En esta línea se debe aplicar el logaritmo natural a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf1, bins=10, kde=True)                              #  En este línea agrega el comando para obtener el histograma de Transf2 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Logaritmo')



    # Datos transformados con la potencia de 2 ---------------------------------
    plt.subplot(5,columns,k+40)

    Transf3 = np.power(misdatos[variables_a_transformar[k]], .23)  #  En esta línea debes elevar al cuadrado los valores de cada variable "k" sin transformar.
    sns.histplot(Transf3, bins=10, kde=True)                               #  En este línea agrega el comando para obtener el histograma de Transf3 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Potencia 2')


    # Datos transformados con Box-Cox ------------------------------------------
    plt.subplot(5,columns,k+53)

    Transf4 = power_transform(misdatos[variables_a_transformar[k]].values.reshape(-1,1), method='yeo-johnson') #  En esta línea se debe aplicar la transformación Box-Cox a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf4, bins=10, kde=True)                    #  En este línea agrega el comando para obtener el histograma de Transf4 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('yeo-johnson')

    # TERMINA LA SECCIÓN PARA AGREGAR CÓDIGO.
    ################################################################################################################



plt.show()

# %% [markdown]
# DistanceFromHome            = True -> YeoJohnson
# percentSalaryHike           = True -> YeoJohnson
# MonthlyIncome               = True -> CBRT
# YearsAtCompany              = True -> CBRT
# YearsSinceLastPromotion     = True -> CBRT
# YearsWithCurrManager        = True -> SQRT
# YearsInCurrentRole          = True -> SQRT
# TotalWorkingYars            = True -> SQRT
# NumCompaniesWorked          = True -> SQRT
# DayliRate                   = False
# HourlyRate                  = False
# MonthlyRate                 = False
# TrainningTimesLastYear      = False

# %%
#XtrainT, XvalT y XtestT.
XtrainT = Xtrain.copy()
XvalT = Xval.copy()
XtestT = Xtest.copy()

XtrainT
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 99     44         Non-Travel        489  Research & Development
# 785    40      Travel_Rarely       1492  Research & Development
# 918    51  Travel_Frequently        237                   Sales
# 1335   39      Travel_Rarely        835  Research & Development
# 1182   36         Non-Travel        894  Research & Development
# ...   ...                ...        ...                     ...
# 715    33  Travel_Frequently        827  Research & Development
# 905    29      Travel_Rarely        694  Research & Development
# 1096   40      Travel_Rarely        898         Human Resources
# 235    43      Travel_Rarely       1034                   Sales
# 1061   24         Non-Travel        830                   Sales
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 99                  23          3           Medical                        2
# 785                 20          4  Technical Degree                        1
# 918                  9          3     Life Sciences                        4
# 1335                19          4             Other                        4
# 1182                 1          4           Medical                        4
# ...                ...        ...               ...                      ...
# 715                  1          4             Other                        3
# 905                  1          3     Life Sciences                        4
# 1096                 6          2           Medical                        3
# 235                 16          3         Marketing                        4
# 1061                13          2     Life Sciences                        4
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 99      Male          67  ...                  3                         3
# 785     Male          61  ...                  4                         4
# 918     Male          83  ...                  4                         1
# 1335    Male          41  ...                  3                         2
# 1182  Female          33  ...                  3                         3
# ...      ...         ...  ...                ...                       ...
# 715   Female          84  ...                  3                         1
# 905   Female          87  ...                  3                         2
# 1096    Male          38  ...                  4                         4
# 235   Female          80  ...                  4                         3
# 1061  Female          78  ...                  3                         3
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 99                  1                 17                     3
# 785                 1                 14                     6
# 918                 1                 31                     5
# 1335                3                  7                     2
# 1182                0                  4                     6
# ...               ...                ...                   ...
# 715                 1                  6                     2
# 905                 2                  9                     2
# 1096                0                 21                     2
# 235                 1                 22                     3
# 1061                1                  1                     2
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 99                  4               3                   2
# 785                 3              11                  10
# 918                 2              29                  10
# 1335                3               2                   2
# 1182                3               3                   2
# ...               ...             ...                 ...
# 715                 3               6                   5
# 905                 2               7                   7
# 1096                3              21                   7
# 235                 3              17                  13
# 1061                3               1                   0
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 99                         1                     2
# 785                       11                     1
# 918                       11                    10
# 1335                       2                     2
# 1182                       1                     2
# ...                      ...                   ...
# 715                        1                     2
# 905                        1                     7
# 1096                       7                     7
# 235                        1                     9
# 1061                       0                     0
#
# [1029 rows x 30 columns]

# %%
YeoJohnson = ['DistanceFromHome', 'PercentSalaryHike']
CBRTt = ['MonthlyIncome', 'YearsAtCompany', 'YearsSinceLastPromotion']
SQRTt = ['NumCompaniesWorked', 'TotalWorkingYears', 'YearsInCurrentRole', 'YearsWithCurrManager']

# TRANS RAIZ CUADRADA
XtrainT[SQRTt] = np.sqrt(XtrainT[SQRTt])
XvalT[SQRTt] = np.sqrt(XvalT[SQRTt])
XtestT[SQRTt] = np.sqrt(XtestT[SQRTt])

# Transformación Raiz cubica
XtrainT[CBRTt] = np.log1p(XtrainT[CBRTt])
XvalT[CBRTt] = np.log1p(XvalT[CBRTt])
XtestT[CBRTt] = np.log1p(XtestT[CBRTt])


# Transformación Yeo-Johnson
XtrainT[YeoJohnson] = power_transform(XtrainT[YeoJohnson], method='yeo-johnson')
XvalT[YeoJohnson] = power_transform(XvalT[YeoJohnson], method='yeo-johnson')
XtestT[YeoJohnson] = power_transform(XtestT[YeoJohnson], method='yeo-johnson')


#HAGO MIS VARIABLES 
ytrainT = ytrain.copy()
yvalT = yval.copy()
ytestT = ytest.copy()

# %% [markdown]
#       *   Attrition
#       *   Gender
#       *   Over18
#       *   OverTime

# %%
binaryColumns = ["Gender", "OverTime"]
le = LabelEncoder()
# Transformación de las variables binarias con LabelEncoder 
for i in binaryColumns:
    XtrainT[i]
    le.fit(XtrainT[i])
    XtrainT[i] = le.transform(XtrainT[i])
    XvalT[i] = le.transform(XvalT[i])
    XtestT[i] = le.transform(XtestT[i])

# %%
XtrainT[binaryColumns]
# Out:
#       Gender  OverTime
# 99         1         0
# 785        1         0
# 918        1         1
# 1335       1         0
# 1182       0         0
# ...      ...       ...
# 715        0         1
# 905        0         0
# 1096       1         1
# 235        0         1
# 1061       0         0
#
# [1029 rows x 2 columns]

# %%
XvalT[binaryColumns]
# Out:
#       Gender  OverTime
# 920        0         0
# 81         1         0
# 685        1         0
# 1398       1         0
# 375        1         0
# ...      ...       ...
# 950        0         1
# 817        1         0
# 679        0         0
# 1271       1         0
# 659        1         0
#
# [221 rows x 2 columns]

# %%
XtestT[binaryColumns]
# Out:
#       Gender  OverTime
# 368        1         1
# 94         1         0
# 735        1         0
# 986        1         1
# 559        1         1
# ...      ...       ...
# 571        0         0
# 1434       1         0
# 1237       1         0
# 985        1         1
# 863        1         0
#
# [220 rows x 2 columns]

# %%
le.fit(ytrainT)
ytrainT=le.transform(ytrainT)
yvalT=le.transform
yTestT=le.transform

# %%
variables_a_transformar_ordinales=['PerformanceRating',
'EnvironmentSatisfaction',
'JobInvolvement',
'JobSatisfaction',
'RelationshipSatisfaction',
'WorkLifeBalance',
'Education']

# %%
XtrainT[variables_a_transformar_ordinales].nunique()
# Out:
# PerformanceRating           2
# EnvironmentSatisfaction     4
# JobInvolvement              4
# JobSatisfaction             4
# RelationshipSatisfaction    4
# WorkLifeBalance             4
# Education                   5
# dtype: int64

# %% [markdown]
# Los valores de estas variables ordinales ya estan en valores enteros. Por lo que no se necesita hacerle ninguna transformacion.
#
# Por ejemplo:
#
# Education
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# Si los valores esubieran en String si se deberia de transformar. Overtime estaba con valoes ['Yes', 'No'] se trandfaron a ['1','0']

# %%
XtrainT.shape
# Out:
# (1029, 30)

# %%
XtrainT
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 99     44         Non-Travel        489  Research & Development
# 785    40      Travel_Rarely       1492  Research & Development
# 918    51  Travel_Frequently        237                   Sales
# 1335   39      Travel_Rarely        835  Research & Development
# 1182   36         Non-Travel        894  Research & Development
# ...   ...                ...        ...                     ...
# 715    33  Travel_Frequently        827  Research & Development
# 905    29      Travel_Rarely        694  Research & Development
# 1096   40      Travel_Rarely        898         Human Resources
# 235    43      Travel_Rarely       1034                   Sales
# 1061   24         Non-Travel        830                   Sales
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 99            1.428407          3           Medical                        2
# 785           1.265938          4  Technical Degree                        1
# 918           0.372845          3     Life Sciences                        4
# 1335          1.206708          4             Other                        4
# 1182         -1.509525          4           Medical                        4
# ...                ...        ...               ...                      ...
# 715          -1.509525          4             Other                        3
# 905          -1.509525          3     Life Sciences                        4
# 1096         -0.050747          2           Medical                        3
# 235           1.009922          3         Marketing                        4
# 1061          0.775854          2     Life Sciences                        4
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 99         1          67  ...                  3                         3
# 785        1          61  ...                  4                         4
# 918        1          83  ...                  4                         1
# 1335       1          41  ...                  3                         2
# 1182       0          33  ...                  3                         3
# ...      ...         ...  ...                ...                       ...
# 715        0          84  ...                  3                         1
# 905        0          87  ...                  3                         2
# 1096       1          38  ...                  4                         4
# 235        0          80  ...                  4                         3
# 1061       0          78  ...                  3                         3
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 99                  1           4.123106                     3
# 785                 1           3.741657                     6
# 918                 1           5.567764                     5
# 1335                3           2.645751                     2
# 1182                0           2.000000                     6
# ...               ...                ...                   ...
# 715                 1           2.449490                     2
# 905                 2           3.000000                     2
# 1096                0           4.582576                     2
# 235                 1           4.690416                     3
# 1061                1           1.000000                     2
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 99                  4        1.386294            1.414214
# 785                 3        2.484907            3.162278
# 918                 2        3.401197            3.162278
# 1335                3        1.098612            1.414214
# 1182                3        1.386294            1.414214
# ...               ...             ...                 ...
# 715                 3        1.945910            2.236068
# 905                 2        2.079442            2.645751
# 1096                3        3.091042            2.645751
# 235                 3        2.890372            3.605551
# 1061                3        0.693147            0.000000
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 99                   0.693147              1.414214
# 785                  2.484907              1.000000
# 918                  2.484907              3.162278
# 1335                 1.098612              1.414214
# 1182                 0.693147              1.414214
# ...                       ...                   ...
# 715                  0.693147              1.414214
# 905                  0.693147              2.645751
# 1096                 2.079442              2.645751
# 235                  0.693147              3.000000
# 1061                 0.000000              0.000000
#
# [1029 rows x 30 columns]

# %%
sns.set(rc={'figure.figsize':(20,12)})
merge = XtrainT
XtrainT.insert(1, "Attrition", ytrainT, True)
Tcorrelation = merge.corr(method='pearson', numeric_only=True)
sns.heatmap(Tcorrelation,xticklabels=Tcorrelation.columns,
            yticklabels=Tcorrelation.columns, annot=True, annot_kws={"size": 6}, linewidth=.5, vmax=1.0)

plt.show()

# %% [markdown]
# *Indica las correlaciones positivas “fuertes” entre pares de factores que encuentres
# dentro de la matriz.
#     Age<->TotalWorkingYears : .67
#     Job Level<->TotalWorkingYears : .78
#     MonthlyIncome<->TotalWorkingYears : .77
#     MonthlyIncome<->JobLevel=.95
#     PerformanceRating<->PercentSalaryHike : .76
#     TotalWorkingyears<->YearsAtCompany : .67
#     YearsAtCompany<->YearswithCurrManager : .77
#     YearsAtCompany<->YearsSinceLastPromotion : .62
#     YearsAtCompany<->YearsInCurrentRole : .76
#     YearsInCurrentRole<->YearswithCurrManager : .73
#
# *Indica las correlaciones negativas “fuertes” entre pares de factores que encuentres
# dentro de la matriz.

# %%
Tcorrelation
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.144154  -0.009053         -0.033327
# Attrition                -0.144154   1.000000  -0.064359          0.101326
# DailyRate                -0.009053  -0.064359   1.000000          0.032234
# DistanceFromHome         -0.033327   0.101326   0.032234          1.000000
# Education                 0.219174  -0.018279   0.017164         -0.014054
# EnvironmentSatisfaction  -0.017017  -0.107685   0.018509          0.006597
# Gender                   -0.028391   0.041081  -0.008658         -0.002161
# HourlyRate                0.024445   0.009009   0.052236         -0.004837
# JobInvolvement            0.009364  -0.116885   0.046388          0.020371
# JobLevel                  0.515152  -0.145600  -0.009675         -0.024434
# JobSatisfaction          -0.032524  -0.058378   0.049870         -0.000635
# MonthlyIncome             0.505701  -0.182881   0.005605         -0.019323
# MonthlyRate               0.028323   0.018729  -0.047170          0.035997
# NumCompaniesWorked        0.325611   0.042029   0.036472          0.000574
# OverTime                  0.004723   0.251005   0.027769          0.050304
# PercentSalaryHike         0.001988  -0.032147   0.003260          0.019842
# PerformanceRating         0.010321  -0.016874  -0.004991          0.008479
# RelationshipSatisfaction  0.054914  -0.025494  -0.004479          0.034965
# StockOptionLevel         -0.004872  -0.132430   0.047608          0.029771
# TotalWorkingYears         0.685208  -0.184829   0.019779         -0.030421
# TrainingTimesLastYear    -0.027238  -0.064991   0.001964         -0.009321
# WorkLifeBalance           0.003927  -0.105012  -0.035080         -0.001348
# YearsAtCompany            0.259784  -0.182535   0.000408         -0.017268
# YearsInCurrentRole        0.200572  -0.176371   0.030285         -0.008118
# YearsSinceLastPromotion   0.188725  -0.020598  -0.036557         -0.003847
# YearsWithCurrManager      0.178745  -0.185082   0.001055         -0.014771
#
#                           Education  EnvironmentSatisfaction    Gender  \
# Age                        0.219174                -0.017017 -0.028391
# Attrition                 -0.018279                -0.107685  0.041081
# DailyRate                  0.017164                 0.018509 -0.008658
# DistanceFromHome          -0.014054                 0.006597 -0.002161
# Education                  1.000000                -0.041465  0.007099
# EnvironmentSatisfaction   -0.041465                 1.000000  0.022372
# Gender                     0.007099                 0.022372  1.000000
# HourlyRate                 0.015255                -0.092448 -0.008706
# JobInvolvement             0.050352                -0.011420  0.011016
# JobLevel                   0.139727                -0.020541 -0.058778
# JobSatisfaction           -0.024094                 0.027626  0.061702
# MonthlyIncome              0.154692                -0.043365 -0.072773
# MonthlyRate               -0.017969                 0.048634 -0.050722
# NumCompaniesWorked         0.134708                 0.015300 -0.036683
# OverTime                  -0.012266                 0.053711 -0.047356
# PercentSalaryHike         -0.010018                -0.045695 -0.009586
# PerformanceRating         -0.035496                -0.039408 -0.028114
# RelationshipSatisfaction  -0.000918                -0.022324  0.009667
# StockOptionLevel           0.005697                 0.025302  0.005291
# TotalWorkingYears          0.179667                -0.022401 -0.055654
# TrainingTimesLastYear     -0.039972                -0.026589 -0.031309
# WorkLifeBalance            0.027394                 0.056270  0.001476
# YearsAtCompany             0.046344                -0.004101 -0.065751
# YearsInCurrentRole         0.047308                 0.013182 -0.060388
# YearsSinceLastPromotion    0.039009                 0.024694 -0.026889
# YearsWithCurrManager       0.045380                -0.008337 -0.072370
#
#                           HourlyRate  JobInvolvement  JobLevel  ...  \
# Age                         0.024445        0.009364  0.515152  ...
# Attrition                   0.009009       -0.116885 -0.145600  ...
# DailyRate                   0.052236        0.046388 -0.009675  ...
# DistanceFromHome           -0.004837        0.020371 -0.024434  ...
# Education                   0.015255        0.050352  0.139727  ...
# EnvironmentSatisfaction    -0.092448       -0.011420 -0.020541  ...
# Gender                     -0.008706        0.011016 -0.058778  ...
# HourlyRate                  1.000000        0.060143 -0.035235  ...
# JobInvolvement              0.060143        1.000000 -0.014525  ...
# JobLevel                   -0.035235       -0.014525  1.000000  ...
# JobSatisfaction            -0.073598       -0.046486 -0.028661  ...
# MonthlyIncome              -0.017679       -0.018626  0.920514  ...
# MonthlyRate                -0.024499       -0.010289  0.058008  ...
# NumCompaniesWorked          0.023258        0.013244  0.172539  ...
# OverTime                   -0.019380       -0.002019  0.009319  ...
# PercentSalaryHike           0.002588       -0.016430 -0.050892  ...
# PerformanceRating          -0.000185       -0.017386 -0.024233  ...
# RelationshipSatisfaction   -0.001286        0.024426  0.020088  ...
# StockOptionLevel            0.041532        0.000031  0.015295  ...
# TotalWorkingYears          -0.017814       -0.005935  0.754118  ...
# TrainingTimesLastYear       0.033486       -0.031107 -0.039631  ...
# WorkLifeBalance             0.010014       -0.013835  0.044062  ...
# YearsAtCompany             -0.030954        0.015967  0.443830  ...
# YearsInCurrentRole         -0.027429        0.031405  0.334774  ...
# YearsSinceLastPromotion    -0.043458       -0.024404  0.290845  ...
# YearsWithCurrManager       -0.038791        0.052300  0.334304  ...
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.010321                  0.054914
# Attrition                         -0.016874                 -0.025494
# DailyRate                         -0.004991                 -0.004479
# DistanceFromHome                   0.008479                  0.034965
# Education                         -0.035496                 -0.000918
# EnvironmentSatisfaction           -0.039408                 -0.022324
# Gender                            -0.028114                  0.009667
# HourlyRate                        -0.000185                 -0.001286
# JobInvolvement                    -0.017386                  0.024426
# JobLevel                          -0.024233                  0.020088
# JobSatisfaction                    0.018225                 -0.014213
# MonthlyIncome                     -0.022691                 -0.000448
# MonthlyRate                        0.009870                 -0.006255
# NumCompaniesWorked                -0.021433                  0.050534
# OverTime                          -0.004904                  0.056089
# PercentSalaryHike                  0.644509                 -0.029067
# PerformanceRating                  1.000000                 -0.028501
# RelationshipSatisfaction          -0.028501                  1.000000
# StockOptionLevel                   0.002615                 -0.074233
# TotalWorkingYears                  0.025870                 -0.002463
# TrainingTimesLastYear              0.004645                  0.008651
# WorkLifeBalance                   -0.008543                  0.032100
# YearsAtCompany                     0.034670                 -0.004256
# YearsInCurrentRole                 0.041236                 -0.011323
# YearsSinceLastPromotion            0.052383                  0.016573
# YearsWithCurrManager               0.014832                  0.008176
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                              -0.004872           0.685208
# Attrition                        -0.132430          -0.184829
# DailyRate                         0.047608           0.019779
# DistanceFromHome                  0.029771          -0.030421
# Education                         0.005697           0.179667
# EnvironmentSatisfaction           0.025302          -0.022401
# Gender                            0.005291          -0.055654
# HourlyRate                        0.041532          -0.017814
# JobInvolvement                    0.000031          -0.005935
# JobLevel                          0.015295           0.754118
# JobSatisfaction                   0.008066          -0.050747
# MonthlyIncome                     0.020465           0.750771
# MonthlyRate                      -0.040200           0.018738
# NumCompaniesWorked                0.018327           0.291391
# OverTime                         -0.019041           0.013303
# PercentSalaryHike                 0.009217          -0.035649
# PerformanceRating                 0.002615           0.025870
# RelationshipSatisfaction         -0.074233          -0.002463
# StockOptionLevel                  1.000000           0.005113
# TotalWorkingYears                 0.005113           1.000000
# TrainingTimesLastYear            -0.004807          -0.044366
# WorkLifeBalance                   0.019264           0.025990
# YearsAtCompany                    0.008975           0.586660
# YearsInCurrentRole                0.036586           0.473291
# YearsSinceLastPromotion          -0.012347           0.360137
# YearsWithCurrManager              0.002501           0.475935
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.027238         0.003927
# Attrition                             -0.064991        -0.105012
# DailyRate                              0.001964        -0.035080
# DistanceFromHome                      -0.009321        -0.001348
# Education                             -0.039972         0.027394
# EnvironmentSatisfaction               -0.026589         0.056270
# Gender                                -0.031309         0.001476
# HourlyRate                             0.033486         0.010014
# JobInvolvement                        -0.031107        -0.013835
# JobLevel                              -0.039631         0.044062
# JobSatisfaction                       -0.031032        -0.016007
# MonthlyIncome                         -0.052688         0.050294
# MonthlyRate                            0.015844        -0.000849
# NumCompaniesWorked                    -0.088111        -0.029879
# OverTime                              -0.075473        -0.028337
# PercentSalaryHike                     -0.002108        -0.008685
# PerformanceRating                      0.004645        -0.008543
# RelationshipSatisfaction               0.008651         0.032100
# StockOptionLevel                      -0.004807         0.019264
# TotalWorkingYears                     -0.044366         0.025990
# TrainingTimesLastYear                  1.000000         0.058622
# WorkLifeBalance                        0.058622         1.000000
# YearsAtCompany                        -0.027389         0.038400
# YearsInCurrentRole                    -0.025987         0.045035
# YearsSinceLastPromotion               -0.018078         0.017907
# YearsWithCurrManager                  -0.034872         0.015753
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.259784            0.200572
# Attrition                      -0.182535           -0.176371
# DailyRate                       0.000408            0.030285
# DistanceFromHome               -0.017268           -0.008118
# Education                       0.046344            0.047308
# EnvironmentSatisfaction        -0.004101            0.013182
# Gender                         -0.065751           -0.060388
# HourlyRate                     -0.030954           -0.027429
# JobInvolvement                  0.015967            0.031405
# JobLevel                        0.443830            0.334774
# JobSatisfaction                -0.009048           -0.030861
# MonthlyIncome                   0.463525            0.371238
# MonthlyRate                    -0.025815           -0.015844
# NumCompaniesWorked             -0.133623           -0.093514
# OverTime                       -0.045408           -0.047050
# PercentSalaryHike              -0.062349           -0.024093
# PerformanceRating               0.034670            0.041236
# RelationshipSatisfaction       -0.004256           -0.011323
# StockOptionLevel                0.008975            0.036586
# TotalWorkingYears               0.586660            0.473291
# TrainingTimesLastYear          -0.027389           -0.025987
# WorkLifeBalance                 0.038400            0.045035
# YearsAtCompany                  1.000000            0.847121
# YearsInCurrentRole              0.847121            1.000000
# YearsSinceLastPromotion         0.547057            0.530686
# YearsWithCurrManager            0.851297            0.769791
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.188725              0.178745
# Attrition                               -0.020598             -0.185082
# DailyRate                               -0.036557              0.001055
# DistanceFromHome                        -0.003847             -0.014771
# Education                                0.039009              0.045380
# EnvironmentSatisfaction                  0.024694             -0.008337
# Gender                                  -0.026889             -0.072370
# HourlyRate                              -0.043458             -0.038791
# JobInvolvement                          -0.024404              0.052300
# JobLevel                                 0.290845              0.334304
# JobSatisfaction                         -0.028555             -0.034879
# MonthlyIncome                            0.290482              0.365585
# MonthlyRate                              0.004176             -0.032722
# NumCompaniesWorked                      -0.043544             -0.115190
# OverTime                                -0.019252             -0.045878
# PercentSalaryHike                       -0.022941             -0.054117
# PerformanceRating                        0.052383              0.014832
# RelationshipSatisfaction                 0.016573              0.008176
# StockOptionLevel                        -0.012347              0.002501
# TotalWorkingYears                        0.360137              0.475935
# TrainingTimesLastYear                   -0.018078             -0.034872
# WorkLifeBalance                          0.017907              0.015753
# YearsAtCompany                           0.547057              0.851297
# YearsInCurrentRole                       0.530686              0.769791
# YearsSinceLastPromotion                  1.000000              0.498892
# YearsWithCurrManager                     0.498892              1.000000
#
# [26 rows x 26 columns]

# %%
nominal_values = ['BusinessTravel','Department','EducationField','MaritalStatus', 'JobRole']
XtrainT = pd.get_dummies(XtrainT, columns=nominal_values, drop_first=True)
XtestT = pd.get_dummies(XtestT, columns=nominal_values, drop_first=True)
XvalT = pd.get_dummies(XvalT, columns=nominal_values, drop_first=True)

XtestT
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 368    40        575          1.337752          2                        3
# 94     32       1093         -0.004762          4                        2
# 735    48        277         -0.004762          3                        1
# 986    39       1498          1.288001          4                        1
# 559    38        268         -0.975188          5                        4
# ...   ...        ...               ...        ...                      ...
# 571    26        575         -1.443804          2                        1
# 1434   52        585          1.634467          4                        1
# 1237   32        964         -1.443804          2                        1
# 985    31        330          1.337752          4                        4
# 863    33        147         -0.975188          3                        2
#
#       Gender  HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  ...  \
# 368        1          68               2         2                3  ...
# 94         1          87               3         2                3  ...
# 735        1          97               2         2                3  ...
# 986        1          44               2         2                4  ...
# 559        1          92               3         1                3  ...
# ...      ...         ...             ...       ...              ...  ...
# 571        0          71               1         1                4  ...
# 1434       1          40               3         1                4  ...
# 1237       1          34               1         2                2  ...
# 985        1          98               3         2                3  ...
# 863        1          99               3         1                3  ...
#
#       MaritalStatus_Married  MaritalStatus_Single  JobRole_Human Resources  \
# 368                       1                     0                        0
# 94                        0                     1                        0
# 735                       0                     1                        0
# 986                       1                     0                        0
# 559                       1                     0                        0
# ...                     ...                   ...                      ...
# 571                       0                     0                        0
# 1434                      0                     0                        0
# 1237                      0                     1                        0
# 985                       1                     0                        0
# 863                       1                     0                        1
#
#       JobRole_Laboratory Technician  JobRole_Manager  \
# 368                               0                0
# 94                                0                0
# 735                               0                0
# 986                               0                0
# 559                               0                0
# ...                             ...              ...
# 571                               1                0
# 1434                              0                0
# 1237                              0                0
# 985                               0                0
# 863                               0                0
#
#       JobRole_Manufacturing Director  JobRole_Research Director  \
# 368                                0                          0
# 94                                 0                          0
# 735                                0                          0
# 986                                0                          0
# 559                                0                          0
# ...                              ...                        ...
# 571                                0                          0
# 1434                               0                          0
# 1237                               0                          0
# 985                                1                          0
# 863                                0                          0
#
#       JobRole_Research Scientist  JobRole_Sales Executive  \
# 368                            0                        1
# 94                             0                        1
# 735                            0                        0
# 986                            0                        1
# 559                            1                        0
# ...                          ...                      ...
# 571                            0                        0
# 1434                           0                        0
# 1237                           0                        1
# 985                            0                        0
# 863                            0                        0
#
#       JobRole_Sales Representative
# 368                              0
# 94                               0
# 735                              0
# 986                              0
# 559                              0
# ...                            ...
# 571                              0
# 1434                             1
# 1237                             0
# 985                              0
# 863                              0
#
# [220 rows x 44 columns]

# %%
XtrainT.head().T
# Out:
#                                            99            785           918   \
# Age                                   44.000000     40.000000     51.000000
# Attrition                              0.000000      0.000000      0.000000
# DailyRate                            489.000000   1492.000000    237.000000
# DistanceFromHome                       1.428407      1.265938      0.372845
# Education                              3.000000      4.000000      3.000000
# EnvironmentSatisfaction                2.000000      1.000000      4.000000
# Gender                                 1.000000      1.000000      1.000000
# HourlyRate                            67.000000     61.000000     83.000000
# JobInvolvement                         3.000000      3.000000      3.000000
# JobLevel                               2.000000      3.000000      5.000000
# JobSatisfaction                        2.000000      4.000000      2.000000
# MonthlyIncome                          7.622175      9.242130      9.895859
# MonthlyRate                        25043.000000  26542.000000  19196.000000
# NumCompaniesWorked                     2.000000      2.000000      2.000000
# OverTime                               0.000000      0.000000      1.000000
# PercentSalaryHike                     -0.955546      1.265820      1.792443
# PerformanceRating                      3.000000      4.000000      4.000000
# RelationshipSatisfaction               3.000000      4.000000      1.000000
# StockOptionLevel                       1.000000      1.000000      1.000000
# TotalWorkingYears                      4.123106      3.741657      5.567764
# TrainingTimesLastYear                  3.000000      6.000000      5.000000
# WorkLifeBalance                        4.000000      3.000000      2.000000
# YearsAtCompany                         1.386294      2.484907      3.401197
# YearsInCurrentRole                     1.414214      3.162278      3.162278
# YearsSinceLastPromotion                0.693147      2.484907      2.484907
# YearsWithCurrManager                   1.414214      1.000000      3.162278
# BusinessTravel_Travel_Frequently       0.000000      0.000000      1.000000
# BusinessTravel_Travel_Rarely           0.000000      1.000000      0.000000
# Department_Research & Development      1.000000      1.000000      0.000000
# Department_Sales                       0.000000      0.000000      1.000000
# EducationField_Life Sciences           0.000000      0.000000      1.000000
# EducationField_Marketing               0.000000      0.000000      0.000000
# EducationField_Medical                 1.000000      0.000000      0.000000
# EducationField_Other                   0.000000      0.000000      0.000000
# EducationField_Technical Degree        0.000000      1.000000      0.000000
# MaritalStatus_Married                  1.000000      1.000000      0.000000
# MaritalStatus_Single                   0.000000      0.000000      0.000000
# JobRole_Human Resources                0.000000      0.000000      0.000000
# JobRole_Laboratory Technician          1.000000      0.000000      0.000000
# JobRole_Manager                        0.000000      0.000000      1.000000
# JobRole_Manufacturing Director         0.000000      0.000000      0.000000
# JobRole_Research Director              0.000000      0.000000      0.000000
# JobRole_Research Scientist             0.000000      0.000000      0.000000
# JobRole_Sales Executive                0.000000      0.000000      0.000000
# JobRole_Sales Representative           0.000000      0.000000      0.000000
#
#                                           1335          1182
# Age                                  39.000000     36.000000
# Attrition                             0.000000      0.000000
# DailyRate                           835.000000    894.000000
# DistanceFromHome                      1.206708     -1.509525
# Education                             4.000000      4.000000
# EnvironmentSatisfaction               4.000000      4.000000
# Gender                                1.000000      0.000000
# HourlyRate                           41.000000     33.000000
# JobInvolvement                        3.000000      2.000000
# JobLevel                              2.000000      2.000000
# JobSatisfaction                       4.000000      3.000000
# MonthlyIncome                         8.269501      8.383662
# MonthlyRate                        5141.000000  15411.000000
# NumCompaniesWorked                    2.828427      0.000000
# OverTime                              0.000000      0.000000
# PercentSalaryHike                    -0.146606      0.172908
# PerformanceRating                     3.000000      3.000000
# RelationshipSatisfaction              2.000000      3.000000
# StockOptionLevel                      3.000000      0.000000
# TotalWorkingYears                     2.645751      2.000000
# TrainingTimesLastYear                 2.000000      6.000000
# WorkLifeBalance                       3.000000      3.000000
# YearsAtCompany                        1.098612      1.386294
# YearsInCurrentRole                    1.414214      1.414214
# YearsSinceLastPromotion               1.098612      0.693147
# YearsWithCurrManager                  1.414214      1.414214
# BusinessTravel_Travel_Frequently      0.000000      0.000000
# BusinessTravel_Travel_Rarely          1.000000      0.000000
# Department_Research & Development     1.000000      1.000000
# Department_Sales                      0.000000      0.000000
# EducationField_Life Sciences          0.000000      0.000000
# EducationField_Marketing              0.000000      0.000000
# EducationField_Medical                0.000000      1.000000
# EducationField_Other                  1.000000      0.000000
# EducationField_Technical Degree       0.000000      0.000000
# MaritalStatus_Married                 0.000000      1.000000
# MaritalStatus_Single                  0.000000      0.000000
# JobRole_Human Resources               0.000000      0.000000
# JobRole_Laboratory Technician         0.000000      0.000000
# JobRole_Manager                       0.000000      0.000000
# JobRole_Manufacturing Director        0.000000      1.000000
# JobRole_Research Director             0.000000      0.000000
# JobRole_Research Scientist            1.000000      0.000000
# JobRole_Sales Executive               0.000000      0.000000
# JobRole_Sales Representative          0.000000      0.000000

# %%
XtrainT.shape
# Out:
# (1029, 45)

# %%
XtestT.shape
# Out:
# (220, 44)

# %%
XvalT.shape
# Out:
# (221, 44)

# %%
plt.figure(figsize=(20, 25))
variables = XtrainT[['Age','Gender','Department_Sales','WorkLifeBalance', 'RelationshipSatisfaction']]
for i, col in enumerate(variables):
    plt.subplot(5,1, i+1)
    sns.countplot(XtrainT, x=XtrainT[col], hue=XtrainT["Attrition"])
plt.show()

# %% [markdown]
# * A las edades 28, 29 y 33, se da mas el Attrition.
# * El genero con mas Attrition es el Hombre(Male).
# * Los empleado que no estan en el departamento de ventas tiene mas Attrition.
# * WorkLifeBalance 3 'Better' tiene mas Attrition.
#   ** El balance entre la vida personal y la laboral debe ser optima(4) para no sufrir de Attrition.
# * RelationshipSatisfaction 3 'High' y 4 'Very High' Tienen mas Attrition.

# %%
#########################################################################
# INICIA LA SECCIÓN PARA AGREGAR CÓDIGO.
# Ejercicio 3

# Incluye aquí las líneas de código que definan a la función: mi_RMSE:
def mi_RMSE(y_val, yhatVal):
  return np.sqrt(np.mean((np.array(y_val) - np.array(yhatVal))**2))



# Incluye aquí las líneas de código que definan a la función: mi_MAE:
def mi_MAE(y_val, yhatVal):
  return np.mean(np.abs((np.array(y_val) - np.array(yhatVal))))


# Incluye aquí las líneas de código que definan a la función: mi_MAPE:
def mi_MAPE(y_val, yhatVal):
  return np.mean(np.abs((np.array(y_val) - np.array(yhatVal))/np.array(y_val))*100)




# TERMINA LA SECCIÓN PARA AGREGAR CÓDIGO.
#########################################################################
