# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import power_transform
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

#aea_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Inteligencia Artificial/WA_Fn-UseC_-HR-Employee-Attrition.csv')
aea_df = pd.read_csv('./WA_Fn-UseC_-HR-Employee-Attrition.csv')
aea_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
aea_df['OverTime']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: object

# %% [markdown]
# Carga la base de datos y realiza los análisis necesarios para responder a las siguientes
# preguntas:
# * a) ¿Cuántas y cuáles de las variables son numéricas?
#   1. i. ¿Cuántas y cuáles de estas variables numéricas son de valor entero?
#   #### 26
#   2. ii. ¿Cuántas y cuáles de estas variables numéricas son de valor real (flotante)?
#   #### 0
#   3. iii. De existir el caso, ¿cuántas y cuáles de estas variables numéricas se pueden
#   anular del problema? Justifica tu respuesta.
#   ####  Employee count: Todos los valores en la tabla son iguales no tiene valor en el analisis.
# ####  StandardHours: Es un valor unico no tiene relevancia en el analisis.
# ####  Employee Number: Es un identificador unico por empleado no tiene relevancia en el analisis.
#
# * b) ¿Cuántas y cuáles de las variables son categóricas?
#
#   ### 9
#
#   1. i. ¿Cuántas y cuáles de estas variables son binarias?
#
#
#
#       *   Attrition
#       *   Gender
#       *   Over18
#       *   OverTime
#
#   2. ii. ¿Cuántas y cuáles de estas variables son nominales? Indica el total de
#   niveles que tiene cada una de estas variables.
#
#
#
#       *   BusinessTravel
#       *   Department
#       *   EducationField
#       *   MaritalStatus
#
#
#   3. iii. ¿Cuántas y cuáles de estas variables son ordinales? Indica el total de niveles
#
#
#
#       *   PerformanceRating
#       *   Education
#       *   EnvironmentSatisfaction
#       *   JobInvolvement
#       *   JobSatisfaction
#       *   RelationshipSatisfaction
#       *   WorkLifeBalance
#
# que tiene cada una de estas variables.
# iv. De existir el caso, ¿cuántas y cuáles de estas variables categóricas se pueden
# anular del problema? Justifica tu respuesta.
#
# Over18 -> todos los valores son iguales
#
# * c) En esta base de datos y con base a la información dada, ¿existe alguna o algunas
# variables cuya clasificación en algún tipo de dato dependa del analista? ¿Cuáles y
# por qué?

# %%
aea_df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
aea_df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %%
aea_df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %%
aea_df.drop(columns=["Over18", "EmployeeCount", "EmployeeNumber", "StandardHours"], inplace=True)

# %%
Xtrain, XTestTemp, ytrain, ytestTemp = train_test_split(aea_df.drop('Attrition', axis=1), aea_df['Attrition'], test_size=0.30, random_state=1)
Xtest, Xval, ytest, yval = train_test_split(XTestTemp, ytestTemp, test_size=0.5, random_state=1)

# %%
Xtrain.select_dtypes(include=['number']).hist(figsize=(30,14), bins=20)
plt.show()

# %% [markdown]
# Yo suguiero transformar con MinMaxScaler() todas las columnas para que esten a la misma escala.

# %%
# Lista de los nombres de las 7 variables que trabajaremos en este ejercicio.
misdatos = Xtrain.select_dtypes(include=['number'])
variables_a_transformar = misdatos
variables_a_transformar
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 99     44        489                23          3                        2
# 785    40       1492                20          4                        1
# 918    51        237                 9          3                        4
# 1335   39        835                19          4                        4
# 1182   36        894                 1          4                        4
# ...   ...        ...               ...        ...                      ...
# 715    33        827                 1          4                        3
# 905    29        694                 1          3                        4
# 1096   40        898                 6          2                        3
# 235    43       1034                16          3                        4
# 1061   24        830                13          2                        4
#
#       HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 99            67               3         2                2           2042
# 785           61               3         3                4          10322
# 918           83               3         5                2          19847
# 1335          41               3         2                4           3902
# 1182          33               2         2                3           4374
# ...          ...             ...       ...              ...            ...
# 715           84               4         2                2           5488
# 905           87               2         4                4          16124
# 1096          38               3         4                4          16437
# 235           80               3         4                4          16064
# 1061          78               3         1                2           2033
#
#       ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 99    ...                  3                         3                 1
# 785   ...                  4                         4                 1
# 918   ...                  4                         1                 1
# 1335  ...                  3                         2                 3
# 1182  ...                  3                         3                 0
# ...   ...                ...                       ...               ...
# 715   ...                  3                         1                 1
# 905   ...                  3                         2                 2
# 1096  ...                  4                         4                 0
# 235   ...                  4                         3                 1
# 1061  ...                  3                         3                 1
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 99                   17                      3                4
# 785                  14                      6                3
# 918                  31                      5                2
# 1335                  7                      2                3
# 1182                  4                      6                3
# ...                 ...                    ...              ...
# 715                   6                      2                3
# 905                   9                      2                2
# 1096                 21                      2                3
# 235                  22                      3                3
# 1061                  1                      2                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 99                 3                   2                        1
# 785               11                  10                       11
# 918               29                  10                       11
# 1335               2                   2                        2
# 1182               3                   2                        1
# ...              ...                 ...                      ...
# 715                6                   5                        1
# 905                7                   7                        1
# 1096              21                   7                        7
# 235               17                  13                        1
# 1061               1                   0                        0
#
#       YearsWithCurrManager
# 99                       2
# 785                      1
# 918                     10
# 1335                     2
# 1182                     2
# ...                    ...
# 715                      2
# 905                      7
# 1096                     7
# 235                      9
# 1061                     0
#
# [1029 rows x 23 columns]

# %%
variables_a_transformar = ['DailyRate', 'DistanceFromHome',
       'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
len(variables_a_transformar)
# Out:
# 13

# %%
sns.set(rc={'figure.figsize':(45,14)})


columns = len(variables_a_transformar)
fig, axes = plt.subplots(5, columns)

for k in range(0,columns):

    # Datos originales ---------------------------------------------------------
    plt.subplot(5,columns,k+1)

    Transf0 = misdatos[variables_a_transformar[k]]         #  En esta línea se debe asignar a Transf0 los valores de cada variable "k" sin transformar.
    sns.histplot(Transf0, bins=10, kde=True)                             #  En este línea agrega el comando para obtener el histograma de Transf0 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Originales')



    # Datos transformados con raíz cuadrada ------------------------------------
    plt.subplot(5,columns,k+14)

    Transf1 = np.cbrt(misdatos[variables_a_transformar[k]])   #  En esta línea se debe aplicar la raíz cuadrada a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf1, bins=10, kde=True)                                #  En este línea agrega el comando para obtener el histograma de Transf1 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Raíz Cuadrada')



    # Datos transformados con logaritmo natural --------------------------------
    plt.subplot(5,columns,k+27)

    Transf2 = np.log(misdatos[variables_a_transformar[k]]+1)  #  En esta línea se debe aplicar el logaritmo natural a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf1, bins=10, kde=True)                              #  En este línea agrega el comando para obtener el histograma de Transf2 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Logaritmo')



    # Datos transformados con la potencia de 2 ---------------------------------
    plt.subplot(5,columns,k+40)

    Transf3 = np.power(misdatos[variables_a_transformar[k]], .23)  #  En esta línea debes elevar al cuadrado los valores de cada variable "k" sin transformar.
    sns.histplot(Transf3, bins=10, kde=True)                               #  En este línea agrega el comando para obtener el histograma de Transf3 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('Potencia 2')


    # Datos transformados con Box-Cox ------------------------------------------
    plt.subplot(5,columns,k+53)

    Transf4 = power_transform(misdatos[variables_a_transformar[k]].values.reshape(-1,1), method='yeo-johnson') #  En esta línea se debe aplicar la transformación Box-Cox a los valores de cada variable "k" sin transformar.
    sns.histplot(Transf4, bins=10, kde=True)                    #  En este línea agrega el comando para obtener el histograma de Transf4 con 20 barras (bins).


    plt.xlabel(variables_a_transformar[k])
    if k==0:
      plt.ylabel('yeo-johnson')

    # TERMINA LA SECCIÓN PARA AGREGAR CÓDIGO.
    ################################################################################################################



plt.show()

# %% [markdown]
# DistanceFromHome            = True -> YeoJohnson
# percentSalaryHike           = True -> YeoJohnson
# MonthlyIncome               = True -> CBRT
# YearsAtCompany              = True -> CBRT
# YearsSinceLastPromotion     = True -> CBRT
# YearsWithCurrManager        = True -> SQRT
# YearsInCurrentRole          = True -> SQRT
# TotalWorkingYars            = True -> SQRT
# NumCompaniesWorked          = True -> SQRT
# DayliRate                   = False
# HourlyRate                  = False
# MonthlyRate                 = False
# TrainningTimesLastYear      = False

# %%
#XtrainT, XvalT y XtestT.
XtrainT = Xtrain.copy()
XvalT = Xval.copy()
XtestT = Xtest.copy()

XtrainT
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 99     44         Non-Travel        489  Research & Development
# 785    40      Travel_Rarely       1492  Research & Development
# 918    51  Travel_Frequently        237                   Sales
# 1335   39      Travel_Rarely        835  Research & Development
# 1182   36         Non-Travel        894  Research & Development
# ...   ...                ...        ...                     ...
# 715    33  Travel_Frequently        827  Research & Development
# 905    29      Travel_Rarely        694  Research & Development
# 1096   40      Travel_Rarely        898         Human Resources
# 235    43      Travel_Rarely       1034                   Sales
# 1061   24         Non-Travel        830                   Sales
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 99                  23          3           Medical                        2
# 785                 20          4  Technical Degree                        1
# 918                  9          3     Life Sciences                        4
# 1335                19          4             Other                        4
# 1182                 1          4           Medical                        4
# ...                ...        ...               ...                      ...
# 715                  1          4             Other                        3
# 905                  1          3     Life Sciences                        4
# 1096                 6          2           Medical                        3
# 235                 16          3         Marketing                        4
# 1061                13          2     Life Sciences                        4
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 99      Male          67  ...                  3                         3
# 785     Male          61  ...                  4                         4
# 918     Male          83  ...                  4                         1
# 1335    Male          41  ...                  3                         2
# 1182  Female          33  ...                  3                         3
# ...      ...         ...  ...                ...                       ...
# 715   Female          84  ...                  3                         1
# 905   Female          87  ...                  3                         2
# 1096    Male          38  ...                  4                         4
# 235   Female          80  ...                  4                         3
# 1061  Female          78  ...                  3                         3
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 99                  1                 17                     3
# 785                 1                 14                     6
# 918                 1                 31                     5
# 1335                3                  7                     2
# 1182                0                  4                     6
# ...               ...                ...                   ...
# 715                 1                  6                     2
# 905                 2                  9                     2
# 1096                0                 21                     2
# 235                 1                 22                     3
# 1061                1                  1                     2
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 99                  4               3                   2
# 785                 3              11                  10
# 918                 2              29                  10
# 1335                3               2                   2
# 1182                3               3                   2
# ...               ...             ...                 ...
# 715                 3               6                   5
# 905                 2               7                   7
# 1096                3              21                   7
# 235                 3              17                  13
# 1061                3               1                   0
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 99                         1                     2
# 785                       11                     1
# 918                       11                    10
# 1335                       2                     2
# 1182                       1                     2
# ...                      ...                   ...
# 715                        1                     2
# 905                        1                     7
# 1096                       7                     7
# 235                        1                     9
# 1061                       0                     0
#
# [1029 rows x 30 columns]

# %%
YeoJohnson = ['DistanceFromHome', 'PercentSalaryHike']
CBRTt = ['MonthlyIncome', 'YearsAtCompany', 'YearsSinceLastPromotion']
SQRTt = ['NumCompaniesWorked', 'TotalWorkingYears', 'YearsInCurrentRole', 'YearsWithCurrManager']

# TRANS RAIZ CUADRADA
XtrainT[SQRTt] = np.sqrt(XtrainT[SQRTt])
XvalT[SQRTt] = np.sqrt(XvalT[SQRTt])
XtestT[SQRTt] = np.sqrt(XtestT[SQRTt])

# Transformación Raiz cubica
XtrainT[CBRTt] = np.log1p(XtrainT[CBRTt])
XvalT[CBRTt] = np.log1p(XvalT[CBRTt])
XtestT[CBRTt] = np.log1p(XtestT[CBRTt])


# Transformación Yeo-Johnson
XtrainT[YeoJohnson] = power_transform(XtrainT[YeoJohnson], method='yeo-johnson')
XvalT[YeoJohnson] = power_transform(XvalT[YeoJohnson], method='yeo-johnson')
XtestT[YeoJohnson] = power_transform(XtestT[YeoJohnson], method='yeo-johnson')


#HAGO MIS VARIABLES 
ytrainT = ytrain.copy()
yvalT = yval.copy()
ytestT = ytest.copy()

# %% [markdown]
#       *   Attrition
#       *   Gender
#       *   Over18
#       *   OverTime

# %%
binaryColumns = ["Gender", "OverTime"]
le = LabelEncoder()
# Transformación de las variables binarias con LabelEncoder 
for i in binaryColumns:
    XtrainT[i]
    le.fit(XtrainT[i])
    XtrainT[i] = le.transform(XtrainT[i])
    XvalT[i] = le.transform(XvalT[i])
    XtestT[i] = le.transform(XtestT[i])

# %%
Xtrain[binaryColumns]
# Out:
#       Gender OverTime
# 99      Male       No
# 785     Male       No
# 918     Male      Yes
# 1335    Male       No
# 1182  Female       No
# ...      ...      ...
# 715   Female      Yes
# 905   Female       No
# 1096    Male      Yes
# 235   Female      Yes
# 1061  Female       No
#
# [1029 rows x 2 columns]

# %%
le.fit(ytrainT)
ytrainT=le.transform(ytrainT)
yvalT=le.transform
yTestT=le.transform

# %%
scalar = MinMaxScaler()
x = XtrainT.select_dtypes(include=['number'])
x_scaled = scalar.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled, columns=scalar.get_feature_names_out())

# %%
x_scaled.insert(2, "Attrition", ytrainT, True)

# %%
x_scaled["Attrition"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1024    0
# 1025    0
# 1026    0
# 1027    0
# 1028    0
# Name: Attrition, Length: 1029, dtype: int64

# %%
plt.figure(figsize=(10,8), layout='constrained')
sns.scatterplot(data=x_scaled, x="MonthlyIncome", y="DistanceFromHome", hue="Attrition")
# Out:
# <AxesSubplot: xlabel='MonthlyIncome', ylabel='DistanceFromHome'>

# %%
variables_a_transformar_ordinales=['PerformanceRating',
'EnvironmentSatisfaction',
'JobInvolvement',
'JobSatisfaction',
'RelationshipSatisfaction',
'WorkLifeBalance',
'Education']

# %%
Xtrain[variables_a_transformar_ordinales].nunique()
# Out:
# PerformanceRating           2
# EnvironmentSatisfaction     4
# JobInvolvement              4
# JobSatisfaction             4
# RelationshipSatisfaction    4
# WorkLifeBalance             4
# Education                   5
# dtype: int64

# %% [markdown]
# Los valores de estas variables ordinales ya estan en valores enteros. Por lo que no se necesita hacerle ninguna transformacion.
#
# Por ejemplo:
#
# Education
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# Si los valores esubieran en String si se deberia de transformar. Overtime estaba con valoes ['Yes', 'No'] se trandfaron a ['1','0']

# %%
Xtrain.shape
# Out:
# (1029, 30)

# %%
sns.set(rc={'figure.figsize':(20,12)})
merge = Xtrain
merge.insert(1, "Attrition", ytrainT, True)
Tcorrelation = merge.corr(method='pearson', numeric_only=True)
sns.heatmap(Tcorrelation,xticklabels=Tcorrelation.columns,
            yticklabels=Tcorrelation.columns, annot=True, annot_kws={"size": 8}, linewidth=.5, vmax=1.0)

plt.show()

# %% [markdown]
# *Indica las correlaciones positivas “fuertes” entre pares de factores que encuentres
# dentro de la matriz.
#     Age<->TotalWorkingYears : .67
#     Job Level<->TotalWorkingYears : .78
#     MonthlyIncome<->TotalWorkingYears : .77
#     MonthlyIncome<->JobLevel=.95
#     PerformanceRating<->PercentSalaryHike : .76
#     TotalWorkingyears<->YearsAtCompany : .67
#     YearsAtCompany<->YearswithCurrManager : .77
#     YearsAtCompany<->YearsSinceLastPromotion : .62
#     YearsAtCompany<->YearsInCurrentRole : .76
#     YearsInCurrentRole<->YearswithCurrManager : .73
#
# *Indica las correlaciones negativas “fuertes” entre pares de factores que encuentres
# dentro de la matriz.

# %%
Tcorrelation
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.144154  -0.009053         -0.006900
# Attrition                -0.144154   1.000000  -0.064359          0.099197
# DailyRate                -0.009053  -0.064359   1.000000          0.035864
# DistanceFromHome         -0.006900   0.099197   0.035864          1.000000
# Education                 0.219174  -0.018279   0.017164         -0.012527
# EnvironmentSatisfaction  -0.017017  -0.107685   0.018509          0.005425
# HourlyRate                0.024445   0.009009   0.052236          0.014610
# JobInvolvement            0.009364  -0.116885   0.046388         -0.003813
# JobLevel                  0.515152  -0.145600  -0.009675         -0.001773
# JobSatisfaction          -0.032524  -0.058378   0.049870          0.010962
# MonthlyIncome             0.502331  -0.140143   0.000237         -0.018725
# MonthlyRate               0.028323   0.018729  -0.047170          0.018886
# NumCompaniesWorked        0.309800   0.028527   0.033238         -0.022332
# PercentSalaryHike         0.007566  -0.030557   0.007777          0.049877
# PerformanceRating         0.010321  -0.016874  -0.004991          0.048745
# RelationshipSatisfaction  0.054914  -0.025494  -0.004479          0.032877
# StockOptionLevel         -0.004872  -0.132430   0.047608          0.041056
# TotalWorkingYears         0.682702  -0.149517   0.009992         -0.006681
# TrainingTimesLastYear    -0.027238  -0.064991   0.001964         -0.029969
# WorkLifeBalance           0.003927  -0.105012  -0.035080         -0.003091
# YearsAtCompany            0.299388  -0.119224  -0.027289         -0.005535
# YearsInCurrentRole        0.215653  -0.150998   0.031877          0.006507
# YearsSinceLastPromotion   0.215317  -0.005505  -0.034278          0.011444
# YearsWithCurrManager      0.199587  -0.148284  -0.034041          0.009128
#
#                           Education  EnvironmentSatisfaction  HourlyRate  \
# Age                        0.219174                -0.017017    0.024445
# Attrition                 -0.018279                -0.107685    0.009009
# DailyRate                  0.017164                 0.018509    0.052236
# DistanceFromHome          -0.012527                 0.005425    0.014610
# Education                  1.000000                -0.041465    0.015255
# EnvironmentSatisfaction   -0.041465                 1.000000   -0.092448
# HourlyRate                 0.015255                -0.092448    1.000000
# JobInvolvement             0.050352                -0.011420    0.060143
# JobLevel                   0.139727                -0.020541   -0.035235
# JobSatisfaction           -0.024094                 0.027626   -0.073598
# MonthlyIncome              0.131072                -0.034042   -0.017753
# MonthlyRate               -0.017969                 0.048634   -0.024499
# NumCompaniesWorked         0.146474                 0.022745    0.027306
# PercentSalaryHike         -0.023122                -0.043790    0.002330
# PerformanceRating         -0.035496                -0.039408   -0.000185
# RelationshipSatisfaction  -0.000918                -0.022324   -0.001286
# StockOptionLevel           0.005697                 0.025302    0.041532
# TotalWorkingYears          0.160649                -0.012831   -0.010993
# TrainingTimesLastYear     -0.039972                -0.026589    0.033486
# WorkLifeBalance            0.027394                 0.056270    0.010014
# YearsAtCompany             0.050785                -0.012710   -0.025076
# YearsInCurrentRole         0.048898                 0.019516   -0.028129
# YearsSinceLastPromotion    0.051945                 0.012400   -0.034167
# YearsWithCurrManager       0.058004                -0.001789   -0.043301
#
#                           JobInvolvement  JobLevel  JobSatisfaction  ...  \
# Age                             0.009364  0.515152        -0.032524  ...
# Attrition                      -0.116885 -0.145600        -0.058378  ...
# DailyRate                       0.046388 -0.009675         0.049870  ...
# DistanceFromHome               -0.003813 -0.001773         0.010962  ...
# Education                       0.050352  0.139727        -0.024094  ...
# EnvironmentSatisfaction        -0.011420 -0.020541         0.027626  ...
# HourlyRate                      0.060143 -0.035235        -0.073598  ...
# JobInvolvement                  1.000000 -0.014525        -0.046486  ...
# JobLevel                       -0.014525  1.000000        -0.028661  ...
# JobSatisfaction                -0.046486 -0.028661         1.000000  ...
# MonthlyIncome                  -0.013587  0.950308        -0.029999  ...
# MonthlyRate                    -0.010289  0.058008         0.009773  ...
# NumCompaniesWorked              0.023139  0.167055        -0.059487  ...
# PercentSalaryHike              -0.004111 -0.038399         0.038779  ...
# PerformanceRating              -0.017386 -0.024233         0.018225  ...
# RelationshipSatisfaction        0.024426  0.020088        -0.014213  ...
# StockOptionLevel                0.000031  0.015295         0.008066  ...
# TotalWorkingYears              -0.015530  0.780475        -0.043098  ...
# TrainingTimesLastYear          -0.031107 -0.039631        -0.031032  ...
# WorkLifeBalance                -0.013835  0.044062        -0.016007  ...
# YearsAtCompany                 -0.014463  0.517679        -0.024615  ...
# YearsInCurrentRole              0.022653  0.377936        -0.038320  ...
# YearsSinceLastPromotion        -0.030883  0.329964        -0.040672  ...
# YearsWithCurrManager            0.031749  0.377893        -0.046704  ...
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.010321                  0.054914
# Attrition                         -0.016874                 -0.025494
# DailyRate                         -0.004991                 -0.004479
# DistanceFromHome                   0.048745                  0.032877
# Education                         -0.035496                 -0.000918
# EnvironmentSatisfaction           -0.039408                 -0.022324
# HourlyRate                        -0.000185                 -0.001286
# JobInvolvement                    -0.017386                  0.024426
# JobLevel                          -0.024233                  0.020088
# JobSatisfaction                    0.018225                 -0.014213
# MonthlyIncome                     -0.017264                  0.018362
# MonthlyRate                        0.009870                 -0.006255
# NumCompaniesWorked                -0.033358                  0.051835
# PercentSalaryHike                  0.763422                 -0.035898
# PerformanceRating                  1.000000                 -0.028501
# RelationshipSatisfaction          -0.028501                  1.000000
# StockOptionLevel                   0.002615                 -0.074233
# TotalWorkingYears                  0.025276                  0.013446
# TrainingTimesLastYear              0.004645                  0.008651
# WorkLifeBalance                   -0.008543                  0.032100
# YearsAtCompany                     0.030499                  0.023721
# YearsInCurrentRole                 0.058387                 -0.009448
# YearsSinceLastPromotion            0.063376                  0.023555
# YearsWithCurrManager               0.028197                  0.009590
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                              -0.004872           0.682702
# Attrition                        -0.132430          -0.149517
# DailyRate                         0.047608           0.009992
# DistanceFromHome                  0.041056          -0.006681
# Education                         0.005697           0.160649
# EnvironmentSatisfaction           0.025302          -0.012831
# HourlyRate                        0.041532          -0.010993
# JobInvolvement                    0.000031          -0.015530
# JobLevel                          0.015295           0.780475
# JobSatisfaction                   0.008066          -0.043098
# MonthlyIncome                     0.002192           0.769651
# MonthlyRate                      -0.040200           0.031320
# NumCompaniesWorked                0.023361           0.257869
# PercentSalaryHike                 0.006104          -0.013440
# PerformanceRating                 0.002615           0.025276
# RelationshipSatisfaction         -0.074233           0.013446
# StockOptionLevel                  1.000000          -0.009443
# TotalWorkingYears                -0.009443           1.000000
# TrainingTimesLastYear            -0.004807          -0.041913
# WorkLifeBalance                   0.019264           0.014580
# YearsAtCompany                   -0.014915           0.606514
# YearsInCurrentRole                0.024646           0.458964
# YearsSinceLastPromotion          -0.020137           0.391952
# YearsWithCurrManager             -0.012102           0.456958
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.027238         0.003927
# Attrition                             -0.064991        -0.105012
# DailyRate                              0.001964        -0.035080
# DistanceFromHome                      -0.029969        -0.003091
# Education                             -0.039972         0.027394
# EnvironmentSatisfaction               -0.026589         0.056270
# HourlyRate                             0.033486         0.010014
# JobInvolvement                        -0.031107        -0.013835
# JobLevel                              -0.039631         0.044062
# JobSatisfaction                       -0.031032        -0.016007
# MonthlyIncome                         -0.041408         0.031921
# MonthlyRate                            0.015844        -0.000849
# NumCompaniesWorked                    -0.090344        -0.043867
# PercentSalaryHike                      0.002193        -0.008797
# PerformanceRating                      0.004645        -0.008543
# RelationshipSatisfaction               0.008651         0.032100
# StockOptionLevel                      -0.004807         0.019264
# TotalWorkingYears                     -0.041913         0.014580
# TrainingTimesLastYear                  1.000000         0.058622
# WorkLifeBalance                        0.058622         1.000000
# YearsAtCompany                        -0.008414         0.042957
# YearsInCurrentRole                    -0.013576         0.058048
# YearsSinceLastPromotion               -0.026175         0.019283
# YearsWithCurrManager                  -0.018350         0.024871
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.299388            0.215653
# Attrition                      -0.119224           -0.150998
# DailyRate                      -0.027289            0.031877
# DistanceFromHome               -0.005535            0.006507
# Education                       0.050785            0.048898
# EnvironmentSatisfaction        -0.012710            0.019516
# HourlyRate                     -0.025076           -0.028129
# JobInvolvement                 -0.014463            0.022653
# JobLevel                        0.517679            0.377936
# JobSatisfaction                -0.024615           -0.038320
# MonthlyIncome                   0.494716            0.351332
# MonthlyRate                    -0.019454           -0.018005
# NumCompaniesWorked             -0.094460           -0.080612
# PercentSalaryHike              -0.023299            0.011404
# PerformanceRating               0.030499            0.058387
# RelationshipSatisfaction        0.023721           -0.009448
# StockOptionLevel               -0.014915            0.024646
# TotalWorkingYears               0.606514            0.458964
# TrainingTimesLastYear          -0.008414           -0.013576
# WorkLifeBalance                 0.042957            0.058048
# YearsAtCompany                  1.000000            0.779191
# YearsInCurrentRole              0.779191            1.000000
# YearsSinceLastPromotion         0.618150            0.552363
# YearsWithCurrManager            0.789322            0.749625
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.215317              0.199587
# Attrition                               -0.005505             -0.148284
# DailyRate                               -0.034278             -0.034041
# DistanceFromHome                         0.011444              0.009128
# Education                                0.051945              0.058004
# EnvironmentSatisfaction                  0.012400             -0.001789
# HourlyRate                              -0.034167             -0.043301
# JobInvolvement                          -0.030883              0.031749
# JobLevel                                 0.329964              0.377893
# JobSatisfaction                         -0.040672             -0.046704
# MonthlyIncome                            0.325093              0.346502
# MonthlyRate                              0.013347             -0.033181
# NumCompaniesWorked                      -0.025421             -0.087654
# PercentSalaryHike                        0.006323             -0.020443
# PerformanceRating                        0.063376              0.028197
# RelationshipSatisfaction                 0.023555              0.009590
# StockOptionLevel                        -0.020137             -0.012102
# TotalWorkingYears                        0.391952              0.456958
# TrainingTimesLastYear                   -0.026175             -0.018350
# WorkLifeBalance                          0.019283              0.024871
# YearsAtCompany                           0.618150              0.789322
# YearsInCurrentRole                       0.552363              0.749625
# YearsSinceLastPromotion                  1.000000              0.515820
# YearsWithCurrManager                     0.515820              1.000000
#
# [24 rows x 24 columns]

# %%
nominal_values = ['BusinessTravel',
      'Department',
      'EducationField',
      'MaritalStatus']

# %%
nominal_values = ['BusinessTravel','Department','EducationField','MaritalStatus']
XtrainT = pd.get_dummies(Xtrain, columns=nominal_values, drop_first=True)
XtestT = pd.get_dummies(Xtest, columns=nominal_values, drop_first=True)
XvalT = pd.get_dummies(Xtest, columns=nominal_values, drop_first=True)

XtestT
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 368    40        575                22          2                        3
# 94     32       1093                 6          4                        2
# 735    48        277                 6          3                        1
# 986    39       1498                21          4                        1
# 559    38        268                 2          5                        4
# ...   ...        ...               ...        ...                      ...
# 571    26        575                 1          2                        1
# 1434   52        585                29          4                        1
# 1237   32        964                 1          2                        1
# 985    31        330                22          4                        4
# 863    33        147                 2          3                        2
#
#       Gender  HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 368     Male          68               2         2            Sales Executive
# 94      Male          87               3         2            Sales Executive
# 735     Male          97               2         2  Healthcare Representative
# 986     Male          44               2         2            Sales Executive
# 559     Male          92               3         1         Research Scientist
# ...      ...         ...             ...       ...                        ...
# 571   Female          71               1         1      Laboratory Technician
# 1434    Male          40               3         1       Sales Representative
# 1237    Male          34               1         2            Sales Executive
# 985     Male          98               3         2     Manufacturing Director
# 863     Male          99               3         1            Human Resources
#
#       ...  BusinessTravel_Travel_Rarely  Department_Research & Development  \
# 368   ...                             1                                  0
# 94    ...                             1                                  0
# 735   ...                             1                                  1
# 986   ...                             1                                  0
# 559   ...                             1                                  1
# ...   ...                           ...                                ...
# 571   ...                             0                                  1
# 1434  ...                             0                                  0
# 1237  ...                             1                                  0
# 985   ...                             1                                  1
# 863   ...                             1                                  0
#
#       Department_Sales  EducationField_Life Sciences EducationField_Marketing  \
# 368                  1                             0                        1
# 94                   1                             0                        0
# 735                  0                             1                        0
# 986                  1                             1                        0
# 559                  0                             0                        0
# ...                ...                           ...                      ...
# 571                  0                             1                        0
# 1434                 1                             1                        0
# 1237                 1                             1                        0
# 985                  0                             0                        0
# 863                  0                             0                        0
#
#       EducationField_Medical  EducationField_Other  \
# 368                        0                     0
# 94                         1                     0
# 735                        0                     0
# 986                        0                     0
# 559                        1                     0
# ...                      ...                   ...
# 571                        0                     0
# 1434                       0                     0
# 1237                       0                     0
# 985                        1                     0
# 863                        0                     0
#
#       EducationField_Technical Degree  MaritalStatus_Married  \
# 368                                 0                      1
# 94                                  0                      0
# 735                                 0                      0
# 986                                 0                      1
# 559                                 0                      1
# ...                               ...                    ...
# 571                                 0                      0
# 1434                                0                      0
# 1237                                0                      0
# 985                                 0                      1
# 863                                 0                      1
#
#       MaritalStatus_Single
# 368                      0
# 94                       1
# 735                      1
# 986                      0
# 559                      0
# ...                    ...
# 571                      0
# 1434                     0
# 1237                     1
# 985                      0
# 863                      0
#
# [220 rows x 37 columns]

# %%
XtrainT.shape
# Out:
# (1029, 38)

# %%
XtestT.shape
# Out:
# (220, 37)

# %%
XvalT.shape
# Out:
# (220, 37)
